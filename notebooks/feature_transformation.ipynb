# %%
import pandas as pd

# %% [markdown]
# ## Loading All Data
#
# **Note:** Loading all 183 files at once may consume significant memory.
# Consider loading in batches or using chunking for very large datasets.
#
# ```python
# # Uncomment to load all files (use with caution)
# # df_all = load_all_files()
# # print(f"Full dataset shape: {df_all.shape}")
# ```

# %%
# Alternative: Load files one at a time for memory-efficient processing
# Example: Process each file individually
data_dir = Path('data/raw')  # Relative to project root
pkl_files = sorted(data_dir.glob("*.pkl"))

# Process first file as example
if pkl_files:
    df_single = load_pkl_file(pkl_files[0])
    print(f"Single file shape: {df_single.shape}")
    print(f"File: {pkl_files[0].name}")
    df_single.head()
